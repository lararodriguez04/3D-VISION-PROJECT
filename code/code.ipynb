# %%
import open3d as o3d
import trimesh

# %%
mesh = o3d.io.read_triangle_mesh("C:\\Users\\larar\\OneDrive\\Documentos\\Escritorio\\3D-VISION-PROJECT\\ply_files\\room.ply")
mesh.compute_vertex_normals()
o3d.visualization.draw_geometries([mesh])

# %%
# Load mesh
mesh = trimesh.load("C:\\Users\\larar\\OneDrive\\Documentos\\Escritorio\\3D-VISION-PROJECT\\ply_files\\room.ply")

# Center and scale
mesh.vertices -= mesh.centroid

# Show (uses pyglet by default)
mesh.show()

# %%
mesh = o3d.io.read_triangle_mesh("ply_files/sink.ply")
mesh.compute_vertex_normals()
o3d.visualization.draw_geometries([mesh])

# %%
mesh = o3d.io.read_triangle_mesh("ply_files/toilet.ply")
mesh.compute_vertex_normals()
o3d.visualization.draw_geometries([mesh])
